# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python310\python.exe

# %%
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# from dotenv import load_dotenv
# load_dotenv()  # Load environment variables from .env file

# %%
# load_dotenv()

# %%
# Load the Google API key from the environment and make it available to the runtime
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if GOOGLE_API_KEY:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
else:
    raise EnvironmentError("GOOGLE_API_KEY not found in environment. Add it to a .env file or your shell environment.")

# %%
## Load the model and test it with the simple message

# %%
try:
    from langchain.schema import HumanMessage, SystemMessage
except ImportError:
    from langchain_core.messages import HumanMessage, SystemMessage

from langchain_google_genai import ChatGoogleGenerativeAI

chat = ChatGoogleGenerativeAI()

response = chat.predict_messages([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Write a one-sentence summary of LangChain."),
])

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 2
#       1 try:
# ----> 2     from langchain.schema import HumanMessage, SystemMessage
#       3 except ImportError:
#
# ModuleNotFoundError: No module named 'langchain'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 4
#       2     from langchain.schema import HumanMessage, SystemMessage
#       3 except ImportError:
# ----> 4     from langchain_core.messages import HumanMessage, SystemMessage
#       6 from langchain_google_genai import ChatGoogleGenerativeAI
#       8 chat = ChatGoogleGenerativeAI()
#
# ModuleNotFoundError: No module named 'langchain_core'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from langchain_google_genai import ChatGoogleGenerativeAI
#
# ModuleNotFoundError: No module named 'langchain_google_genai'
